# %% [markdown]
# # Wrangle P.I.S.A. 2012
# #### By Youssef Khattab
#
# All through this NoteBook, I will survey and cleaning information from the PISA 2012 dataset. The reason for this fighting is to have a usable dataframe for the corresponding investigation NoteBook, wherein I will investigate the cleaned dataframe and making inferences from the plots

# %%
# Import required packages
import numpy as np
import pandas as pd

# %%
pisa = pd.read_csv('pisa2012.csv', encoding='ISO-8859-1', sep=',', index_col=0) # Drop First Column 'Unnamed: 0'
pisa.head()
# Out:
# C:\Users\j stock\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (15,16,17,21,22,23,24,25,26,30,31,36,37,45,65,123,155,156,157,158,159,160,161,162,163,164,165,166,167,168,169,170,171,284,285,286,287,288,289,290,291,292,293,294,295,296,297,298,299,300,301,302,303,307,308,309,310,311,312,313,314,315,316,317,318,319,320,321,322,323,324,325,326,327,328,329,330,331,332,333,334,335,336,337,338,339,340,341,342,343,344,345,346,347,348,349,350,351,352,353,354,355,356,357,376,377,378,379,380,381,382,383,384,385,386,387,388,389,390,391,392,393,394,395,396,397,398,399,400,401,402,403,475) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        CNT  SUBNATIO  STRATUM      OECD       NC  SCHOOLID  STIDSTD  ST01Q01  \
# 1  Albania     80000  ALB0006  Non-OECD  Albania         1        1       10
# ...

# %%
# print Data Types and Shape of pisa
print(pisa.dtypes)
print('-'*10)
print(pisa.shape)
print('-'*10)
print(pisa.head(20))
# Out:
# CNT            object
# SUBNATIO        int64
# STRATUM        object
# OECD           object
# NC             object
# SCHOOLID        int64
# STIDSTD         int64
# ST01Q01         int64
# ST02Q01       float64
# ST03Q01         int64
# ST03Q02         int64
# ST04Q01        object
# ST05Q01        object
# ST06Q01       float64
# ST07Q01        object
# ST07Q02        object
# ST07Q03        object
# ST08Q01        object
# ST09Q01        object
# ST115Q01      float64
# ST11Q01        object
# ST11Q02        object
# ST11Q03        object
# ST11Q04        object
# ST11Q05        object
# ST11Q06        object
# ST13Q01        object
# ST14Q01        object
# ST14Q02        object
# ST14Q03        object
#                ...
# W_FSTR55      float64
# W_FSTR56      float64
# W_FSTR57      float64
# W_FSTR58      float64
# W_FSTR59      float64
# W_FSTR60      float64
# W_FSTR61      float64
# W_FSTR62      float64
# W_FSTR63      float64
# W_FSTR64      float64
# ...

# %%
# look an ioformain about data frame
pisa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 485490 entries, 1 to 485490
# Columns: 635 entries, CNT to VER_STU
# dtypes: float64(250), int64(17), object(368)
# memory usage: 2.3+ GB

# %%
# look on all countries included in dataframe 
pisa['CNT'].value_counts()
# Out:
# Mexico                      33806
# Italy                       31073
# Spain                       25313
# Canada                      21544
# Brazil                      19204
# Australia                   14481
# United Kingdom              12659
# United Arab Emirates        11500
# Switzerland                 11229
# Qatar                       10966
# Colombia                     9073
# Finland                      8829
# Belgium                      8597
# Denmark                      7481
# Jordan                       7038
# Chile                        6856
# Thailand                     6606
# Japan                        6351
# Chinese Taipei               6046
# Peru                         6035
# Slovenia                     5911
# Argentina                    5908
# Kazakhstan                   5808
# Portugal                     5722
# Indonesia                    5622
# Singapore                    5546
# Macao-China                  5335
# ...

# %%
# Check Duplicate variables
pisa.drop_duplicates()
# Out:
#             CNT  SUBNATIO  STRATUM      OECD         NC  SCHOOLID  STIDSTD  \
# 1       Albania     80000  ALB0006  Non-OECD    Albania         1        1
# 2       Albania     80000  ALB0006  Non-OECD    Albania         1        2
# 3       Albania     80000  ALB0006  Non-OECD    Albania         1        3
# 4       Albania     80000  ALB0006  Non-OECD    Albania         1        4
# 5       Albania     80000  ALB0006  Non-OECD    Albania         1        5
# 6       Albania     80000  ALB0006  Non-OECD    Albania         1        6
# 7       Albania     80000  ALB0006  Non-OECD    Albania         1        7
# 8       Albania     80000  ALB0006  Non-OECD    Albania         1        8
# 9       Albania     80000  ALB0006  Non-OECD    Albania         1        9
# 10      Albania     80000  ALB0005  Non-OECD    Albania         2       10
# 11      Albania     80000  ALB0005  Non-OECD    Albania         2       11
# ...

# %%
# Check Null values in intreseted columns
columns = ['CNT', 'STIDSTD', 'ST01Q01', 'ST04Q01', 'ST13Q01', 
            'ST17Q01', 'ST28Q01', 'ST57Q01', 'ST57Q02', 'ST57Q03', 
            'ST57Q04', 'ST57Q05', 'MMINS', 'LMINS', 'SMINS',
            'PV1MATH', 'PV2MATH', 'PV3MATH', 'PV4MATH', 'PV5MATH',  
            'PV1READ', 'PV2READ',  'PV3READ', 'PV4READ', 'PV5READ',
            'PV1SCIE', 'PV2SCIE', 'PV3SCIE', 'PV4SCIE', 'PV5SCIE']

for x in columns:
    print(x, pisa[x].isna().sum())
# Out:
# CNT 0
# STIDSTD 0
# ST01Q01 0
# ST04Q01 0
# ST13Q01 27511
# ST17Q01 42229
# ST28Q01 11725
# ST57Q01 184123
# ST57Q02 215682
# ST57Q03 201677
# ST57Q04 205833
# ST57Q05 195988
# MMINS 202187
# LMINS 202624
# SMINS 214576
# PV1MATH 0
# PV2MATH 0
# PV3MATH 0
# PV4MATH 0
# PV5MATH 0
# PV1READ 0
# PV2READ 0
# PV3READ 0
# PV4READ 0
# PV5READ 0
# PV1SCIE 0
# PV2SCIE 0
# PV3SCIE 0
# PV4SCIE 0
# PV5SCIE 0

# %%
# Create copy from dataframe to play with it and edit it easy
pisa_c = pisa.copy()

# %%
# Create new dataframe with only the intersted columns
pisa_c = pisa_c[['CNT', 'STIDSTD', 'ST04Q01', 'ST13Q01', 'ST14Q01', 'ST14Q02', 'ST14Q03', 'ST14Q04', 
                         'ST17Q01', 'ST18Q01', 'ST18Q02', 'ST18Q03', 'ST18Q04', 
                         'ST57Q01', 'ST57Q02', 'ST57Q03', 'ST57Q04', 'ST57Q05', 'MMINS', 
                         'LMINS', 'SMINS', 'PV1MATH', 'PV2MATH', 'PV3MATH', 'PV4MATH', 
                         'PV5MATH', 'PV1READ', 'PV2READ',  'PV3READ', 'PV4READ', 'PV5READ',
                         'PV1SCIE', 'PV2SCIE', 'PV3SCIE', 'PV4SCIE', 'PV5SCIE']]

# %% [markdown]
# ### Create an average of all 'Math', 'Reading', and 'Science' scores <not necessary for each score>

# %%
pisa_c['Average_Math_Score']    = (pisa_c['PV1MATH'] + pisa_c['PV2MATH'] + pisa_c['PV3MATH'] + pisa_c['PV4MATH'] + pisa_c['PV5MATH']) / 5

# Create average of Reading scores
pisa_c['Average_Reading_Score'] = (pisa_c['PV1READ'] + pisa_c['PV2READ'] + pisa_c['PV3READ'] + pisa_c['PV4READ'] + pisa_c['PV5READ']) / 5

# Create average of Science scores
pisa_c['Average_Science_Score'] = (pisa_c['PV1SCIE'] + pisa_c['PV2SCIE'] + pisa_c['PV3SCIE'] + pisa_c['PV4SCIE'] + pisa_c['PV5SCIE']) / 5

# Create average score
pisa_c['Average_Total_Score']   = (pisa_c['Average_Math_Score'] + pisa_c['Average_Reading_Score'] + pisa_c['Average_Science_Score']) / 3

# %%
# Check after aggregation. 
list(pisa_c)
# Out:
# ['CNT',
#  'STIDSTD',
#  'ST04Q01',
#  'ST13Q01',
#  'ST14Q01',
#  'ST14Q02',
#  'ST14Q03',
#  'ST14Q04',
#  'ST17Q01',
#  'ST18Q01',
#  'ST18Q02',
#  'ST18Q03',
#  'ST18Q04',
#  'ST57Q01',
#  'ST57Q02',
#  'ST57Q03',
#  'ST57Q04',
#  'ST57Q05',
#  'MMINS',
#  'LMINS',
#  'SMINS',
#  'PV1MATH',
#  'PV2MATH',
#  'PV3MATH',
#  'PV4MATH',
#  'PV5MATH',
#  'PV1READ',
#  'PV2READ',
#  'PV3READ',
#  'PV4READ',
#  'PV5READ',
#  'PV1SCIE',
#  'PV2SCIE',
#  'PV3SCIE',
#  'PV4SCIE',
#  'PV5SCIE',
#  'Average_Math_Score',
#  'Average_Reading_Score',
#  'Average_Science_Score',
#  'Average_Total_Score']

# %%
# Remove the individual scores for Math, Reading, and Science
pisa_c.drop(columns=['PV1MATH',  'PV2MATH', 'PV3MATH', 'PV4MATH', 'PV5MATH',
                     'PV1READ', 'PV2READ',  'PV3READ', 'PV4READ',  'PV5READ',
                     'PV1SCIE',  'PV2SCIE', 'PV3SCIE',  'PV4SCIE', 'PV5SCIE'], inplace=True)

# %%
# Describe of the Math score
print(pisa_c['Average_Math_Score'].describe())
print('-'*22)

# Describe of the Reading score
print(pisa_c['Average_Reading_Score'].describe())
print('-'*22)

# Describe of the Science score
print(pisa_c['Average_Science_Score'].describe())
print('-'*22)

# Describe of the Total score
print(pisa_c['Average_Total_Score'].describe())
# Out:
# count    485490.000000
# mean        469.651234
# std         100.786610
# min          54.767080
# 25%         396.019620
# 50%         465.734520
# 75%         540.123060
# max         903.107960
# Name: Average_Math_Score, dtype: float64
# ----------------------
# count    485490.000000
# mean        472.006964
# std          98.863310
# min           6.445400
# 25%         405.044200
# 50%         475.477980
# 75%         542.831195
# max         849.359740
# Name: Average_Reading_Score, dtype: float64
# ----------------------
# count    485490.000000
# mean        475.808094
# std          97.998470
# min          25.158540
# 25%         405.762800
# 50%         475.512860
# 75%         546.381920
# max         857.832900
# Name: Average_Science_Score, dtype: float64
# ----------------------
# count    485490.000000
# mean        472.488764
# std          96.036271
# min          77.114593
# 25%         403.992595
# 50%         472.046460
# 75%         541.455700
# ...

# %%
# Explore a sample
pisa_c.sample(10)
# Out:
#                              CNT  STIDSTD ST04Q01  \
# 95018                     Canada    20548  Female
# 123265                Costa Rica       93    Male
# 457759                  Thailand     3382    Male
# 430961                    Serbia     2639  Female
# 37342                    Austria      710  Female
# 183368                   Finland     7693  Female
# 431543                    Serbia     3221  Female
# 118189                  Colombia     4090    Male
# 250710                     Italy    10120    Male
# 406283  Perm(Russian Federation)      889    Male
#
#                                       ST13Q01 ST14Q01 ST14Q02 ST14Q03 ST14Q04  \
# 95018                       <ISCED level 3A>       No      No      No      No
# 123265  She did not complete <ISCED level 1>      NaN     NaN     NaN     NaN
# 457759                       <ISCED level 1>       No      No     NaN      No
# 430961                  <ISCED level 3B, 3C>       No      No      No     NaN
# ...

# %% [markdown]
# ### Change the variable names to be more readable, since they are codes that can only be read with the dictionary

# %%
pisa_c.rename({'CNT': 'Country',
                   'STIDSTD': 'Student ID',
                   'ST04Q01': 'Gender', 
                   'ST13Q01': 'Mother - Highest Schooling', 
                   'ST14Q01': 'Mother Qualifications - ISCED level 6',
                   'ST14Q02': 'Mother Qualifications - ISCED level 5A',
                   'ST14Q03': 'Mother Qualifications - ISCED level 5B',
                   'ST14Q04': 'Mother Qualifications - ISCED level 4',
                   'ST17Q01': 'Father - Highest Schooling',
                   'ST18Q01': 'Father Qualifications - ISCED level 6',
                   'ST18Q02': 'Father Qualifications - ISCED level 5A',
                   'ST18Q03': 'Father Qualifications - ISCED level 5B',
                   'ST18Q04': 'Father Qualifications - ISCED level 4',
                   'ST57Q01': 'Out-of-School Study Time - Homework',
                   'ST57Q02': 'Out-of-School Study Time - Guided Homework',
                   'ST57Q03': 'Out-of-School Study Time - Personal Tutor',
                   'ST57Q04': 'Out-of-School Study Time - Commercial Company',
                   'ST57Q05': 'Out-of-School Study Time - With Parent',
                   'MMINS': 'Learning Time - Mathematics',
                   'LMINS': 'Learning Time - Test Language',
                   'SMINS': 'Learning Time - Science'}, axis='columns', inplace=True)

# %% [markdown]
# ### Take action for multiple columns for single variables related to father's education
#
# Values for the father's education are distributed among 5 columns accordance to this classification: http://uis.unesco.org/sites/default/files/documents/international-standard-classification-of-education-isced-2011-en.pdf
# I will have to expand the first column by creating dummies for each data to have a column, and then melt all the columns into one.

# %%
#Make a copy 
f_edu = pisa_c.copy()

# %%
# Split column up with dummies
f_edu[['<ISCED level 1>',
       '<ISCED level 2>', 
        '<ISCED level 3A>', 
        '<ISCED level 3B, 3C>', 
        'He did not complete <ISCED level 1>']] = pd.get_dummies(f_edu['Father - Highest Schooling'])

# %%
# Rename the columns for consistency and to remove subcategorization of levels
f_edu.rename({'He did not complete <ISCED level 1>': '<ISCED level 0>',
                   '<ISCED level 3A>': '<ISCED level 3>', 
                   '<ISCED level 3B, 3C>': '<ISCED level 3>',
                   'Father Qualifications - ISCED level 4': '<ISCED level 4>',
                   'Father Qualifications - ISCED level 5A': '<ISCED level 5>',
                   'Father Qualifications - ISCED level 5B': '<ISCED level 5>',
                   'Father Qualifications - ISCED level 6': '<ISCED level 6>'}, axis='columns', inplace=True)

# %%
# Change datatypes from ints into strings for dummy columns
f_edu['<ISCED level 0>'] = f_edu['<ISCED level 0>'].astype(str)
f_edu['<ISCED level 1>'] = f_edu['<ISCED level 1>'].astype(str)
f_edu['<ISCED level 2>'] = f_edu['<ISCED level 2>'].astype(str)
f_edu['<ISCED level 3>'] = f_edu['<ISCED level 3>'].astype(str)

# %%
# Change values from '1's and 'Yes's to the corresponding level to prepare for the melt
f_edu['<ISCED level 0>'] = f_edu['<ISCED level 0>'].replace(regex='1', value='Early childhood')
f_edu['<ISCED level 1>'] = f_edu['<ISCED level 1>'].replace(regex='1', value='Primary')
f_edu['<ISCED level 2>'] = f_edu['<ISCED level 2>'].replace(regex='1', value='Lower secondary')
f_edu['<ISCED level 3>'] = f_edu['<ISCED level 3>'].replace(regex='1', value='Upper secondary')
f_edu['<ISCED level 4>'] = f_edu['<ISCED level 4>'].replace(regex='Yes', value='Post-secondary')
f_edu['<ISCED level 5>'] = f_edu['<ISCED level 5>'].replace(regex='Yes', value='Short-cycle tertiary')
f_edu['<ISCED level 6>'] = f_edu['<ISCED level 6>'].replace(regex='Yes', value='Bachelor’s or equivalent')

# %%
# Test to see if the columns are all correct before melt
f_edu.sample(10)
# Out:
#                      Country  Student ID  Gender Mother - Highest Schooling  \
# 5995    United Arab Emirates        1252  Female          <ISCED level 3A>
# 449500        Chinese Taipei        1169  Female          <ISCED level 3A>
# 165971                 Spain       20388  Female          <ISCED level 3A>
# 100324           Switzerland        4310  Female      <ISCED level 3B, 3C>
# 270382                 Italy       29792  Female          <ISCED level 3A>
# 176207               Finland         532  Female      <ISCED level 3B, 3C>
# 333490                Mexico       17787    Male      <ISCED level 3B, 3C>
# 303339            Luxembourg        2535    Male          <ISCED level 3A>
# 391835                 Qatar        2584    Male                        NaN
# 113040                 Chile        5797  Female          <ISCED level 3A>
#
#        Mother Qualifications - ISCED level 6  \
# 5995                                      No
# 449500                                   NaN
# ...

# %%
# Combine all columns into one variable column
f_edu = pd.melt(f_edu, 
                     id_vars=['Country','Student ID', 'Gender',
                            'Mother - Highest Schooling', 
                            'Mother Qualifications - ISCED level 6', 
                            'Mother Qualifications - ISCED level 5A',
                            'Mother Qualifications - ISCED level 5B',
                            'Mother Qualifications - ISCED level 4',
                            'Out-of-School Study Time - Homework',
                            'Out-of-School Study Time - Guided Homework',
                            'Out-of-School Study Time - Personal Tutor',
                            'Out-of-School Study Time - Commercial Company',
                            'Out-of-School Study Time - With Parent',
                            'Learning Time - Mathematics',
                            'Learning Time - Test Language',
                            'Learning Time - Science',
                            'Average_Math_Score',
                            'Average_Reading_Score',
                            'Average_Science_Score',
                            'Average_Total_Score'], var_name='Completed_edu - Father', value_name='Education - Father')

# %%
# Check to see if the columns from the melt were correctly created
f_edu.sample(10)
# Out:
#                       Country  Student ID  Gender Mother - Highest Schooling  \
# 3613294               Croatia        3294    Male          <ISCED level 3A>
# 4179521                 Korea        4742    Male          <ISCED level 3A>
# 1899287              Slovenia        5134    Male      <ISCED level 3B, 3C>
# 1631018               Estonia        3653  Female           <ISCED level 2>
# 718822                Iceland        1306  Female           <ISCED level 2>
# 940801               Thailand         935  Female          <ISCED level 3A>
# 529834                Belgium        2958  Female           <ISCED level 2>
# 2944287             Australia        9197  Female           <ISCED level 2>
# 977814   United Arab Emirates        2092    Male                        NaN
# 1042318                Brazil       16073    Male          <ISCED level 3A>
#
#         Mother Qualifications - ISCED level 6  \
# 3613294                                    No
# ...

# %%
# Clean all cases from melt where the edu of the father is either '0' or 'No'
f_edu = f_edu[(f_edu['Education - Father'] != '0')] 
f_edu = f_edu[(f_edu['Education - Father'] != 'No')]

# %%
# Check to see if 0's and No's have been removed
f_edu.sample(70)
# Out:
#                       Country  Student ID  Gender  \
# 224427              Indonesia        3039  Female
# 1491420             Australia       12800  Female
# 51164                Bulgaria        1181    Male
# 128334         Czech Republic         561    Male
# 3181724                 Italy       28195  Female
# 4487726              Colombia        4218    Male
# 3653476                 Italy       14457    Male
# 2214039                Jordan         417    Male
# 2368428             Singapore        3693  Female
# 1715403                 Italy       18344    Male
# 160570                  Spain       14988    Male
# 1769130           Macao-China        2293    Male
# 376424                   Peru        3538    Male
# 3849214        Chinese Taipei        2454  Female
# 223826              Indonesia        2438  Female
# 148512                  Spain        2930    Male
# 1288749                Mexico        2067  Female
# 2632007                Greece        2782    Male
# ...

# %%
# Remove 'Father - Highest Schooling' since it is redundant
f_edu = f_edu[(f_edu['Completed_edu - Father'] != 'Father - Highest Schooling')]

# %%
# Check to see if correct values remain
f_edu['Education - Father'].value_counts()
# Out:
# Upper secondary             306459
# Short-cycle tertiary        185130
# Lower secondary              84329
# Post-secondary               77265
# Primary                      35938
# Bachelor’s or equivalent     29589
# Early childhood              16535
# Name: Education - Father, dtype: int64

# %%
# Completed_edu is no longer needed since it duplicates the information in 'Education - Father'
f_edu.drop(columns=['Completed_edu - Father'], axis=1, inplace=True)

# %%
# Check the column has been dropped
f_edu.sample(10)
# Out:
#                  Country  Student ID  Gender  \
# 692711   Hong Kong-China         321    Male
# 1162308   United Kingdom        2212    Male
# 3729265           Mexico       15133  Female
# 1840319         Portugal         321    Male
# 2267801           Mexico       10139  Female
# 821502            Mexico       20310  Female
# 3935852         Bulgaria        1949  Female
# 2096931            Spain        9389    Male
# 1278277           Latvia        1236  Female
# 1620857            Spain       18805  Female
#
#                     Mother - Highest Schooling  \
# 692711                   <ISCED level 3B, 3C>
# 1162308                      <ISCED level 3A>
# 3729265                       <ISCED level 2>
# 1840319                       <ISCED level 1>
# 2267801  She did not complete <ISCED level 1>
# 821502                        <ISCED level 2>
# 3935852                  <ISCED level 3B, 3C>
# 2096931                  <ISCED level 3B, 3C>
# ...

# %%
# Check if there are any duplicated values 
f_edu['Student ID'].duplicated().sum()
# Out:
# 1229261

# %%
f_edu.dropna(inplace = True)

# %%
# Change datatypes into category, and put into order from lowest to highest
f_edu['Education - Father'] = f_edu['Education - Father'].astype('category')
f_edu['Education - Father'] = f_edu['Education - Father'].cat.set_categories(['Bachelor’s or equivalent','Short-cycle tertiary','Post-secondary',
                                                                              'Upper secondary',
                                                                              'Lower secondary', 
                                                                              'Primary', 
                                                                              'Early childhood'], ordered=True)
f_edu.sort_values(['Education - Father'], inplace=True)

# %%
# Remove duplicates and keep last, which is the highest level of education for the student's father
f_edu_clean = f_edu.drop_duplicates(subset=['Student ID'], keep='first')

# %%
# Ensure there are no duplicates
f_edu_clean['Student ID'].duplicated().sum()
# Out:
# 0

# %%
# Check the size of the dataframe - 
print(pisa['STIDSTD'].nunique(), f_edu_clean.shape)
# Out:
# 33806 (24168, 21)

# %%
# Final check
f_edu.sample(100)
# Out:
#                           Country  Student ID  Gender  \
# 3301055                  Portugal        4587    Male
# 1564701                     Chile         989    Male
# 2583079                     Spain       10047  Female
# 4061615                   Finland        2021    Male
# 3485389                    Canada       12490    Male
# 2306028                    Norway         159    Male
# 3494067                    Canada       21168    Male
# 3807667         Connecticut (USA)         187  Female
# 4263465                    Poland         624    Male
# 3806256             Florida (USA)         672    Male
# 1015383                   Belgium        3017  Female
# 1688356                   Ireland        4876    Male
# 3657491                     Italy       18472  Female
# 1168061            United Kingdom        7965  Female
# 2024997                    Canada        8568    Male
# 2246751                Luxembourg        3988    Male
# ...

# %% [markdown]
# ### There are multiple columns for single variables related to mother's education
# Precisely the same interaction for the mother's edu. is followed with respect to the father's edu.

# %%
# make a copy
m_edu = f_edu_clean.copy()

# %%
m_edu.head()
# Out:
#         Country  Student ID  Gender Mother - Highest Schooling  \
# 485493  Albania           4  Female      <ISCED level 3B, 3C>
# 731111    Italy        5032    Male      <ISCED level 3B, 3C>
# 730790    Italy        4711  Female          <ISCED level 3A>
# 730787    Italy        4708    Male      <ISCED level 3B, 3C>
# 730785    Italy        4706  Female          <ISCED level 3A>
#
#        Mother Qualifications - ISCED level 6  \
# 485493                                    No
# 731111                                    No
# 730790                                   Yes
# 730787                                    No
# 730785                                    No
#
#        Mother Qualifications - ISCED level 5A  \
# 485493                                     No
# 731111                                     No
# 730790                                    Yes
# 730787                                    Yes
# 730785                                     No
#
# ...

# %%
# Compare original dataframe to father dataframe
print(pisa_c['Mother - Highest Schooling'].value_counts())
print('-'*100)
print(m_edu['Mother - Highest Schooling'].value_counts())
# Out:
# <ISCED level 3A>                         236993
# <ISCED level 3B, 3C>                      83048
# <ISCED level 2>                           82614
# <ISCED level 1>                           36556
# She did not complete <ISCED level 1>      18768
# Name: Mother - Highest Schooling, dtype: int64
# ----------------------------------------------------------------------------------------------------
# <ISCED level 3A>                         15383
# <ISCED level 3B, 3C>                      4057
# <ISCED level 2>                           3964
# <ISCED level 1>                            588
# She did not complete <ISCED level 1>       176
# Name: Mother - Highest Schooling, dtype: int64

# %%
# Split column up with dummies
m_edu[['<ISCED level 1>', 
            '<ISCED level 2>', 
            '<ISCED level 3A>', 
            '<ISCED level 3B, 3C>', 
            'She did not complete <ISCED level 1>']] = pd.get_dummies(m_edu['Mother - Highest Schooling'])

# %%
# Rename the columns for consistency and to remove subcategorization of levels
m_edu.rename({'She did not complete <ISCED level 1>': '<ISCED level 0>',
                   '<ISCED level 3A>': '<ISCED level 3>', 
                   '<ISCED level 3B, 3C>': '<ISCED level 3>',
                   'Mother Qualifications - ISCED level 4': '<ISCED level 4>',
                   'Mother Qualifications - ISCED level 5A': '<ISCED level 5>',
                   'Mother Qualifications - ISCED level 5B': '<ISCED level 5>',
                   'Mother Qualifications - ISCED level 6': '<ISCED level 6>'}, axis='columns', inplace=True)

# %%
# Change datatypes from ints into strings for dummy columns
m_edu['<ISCED level 0>'] = m_edu['<ISCED level 0>'].astype(str)
m_edu['<ISCED level 1>'] = m_edu['<ISCED level 1>'].astype(str)
m_edu['<ISCED level 2>'] = m_edu['<ISCED level 2>'].astype(str)
m_edu['<ISCED level 3>'] = m_edu['<ISCED level 3>'].astype(str)

# %%
# Change values from '1's and 'Yes's to the corresponding level to prepare for the melt
m_edu['<ISCED level 0>'] = m_edu['<ISCED level 0>'].replace(regex='1', value='Early childhood')
m_edu['<ISCED level 1>'] = m_edu['<ISCED level 1>'].replace(regex='1', value='Primary')
m_edu['<ISCED level 2>'] = m_edu['<ISCED level 2>'].replace(regex='1', value='Lower secondary')
m_edu['<ISCED level 3>'] = m_edu['<ISCED level 3>'].replace(regex='1', value='Upper secondary')
m_edu['<ISCED level 4>'] = m_edu['<ISCED level 4>'].replace(regex='Yes', value='Post-secondary')
m_edu['<ISCED level 5>'] = m_edu['<ISCED level 5>'].replace(regex='Yes', value='Short-cycle tertiary')
m_edu['<ISCED level 6>'] = m_edu['<ISCED level 6>'].replace(regex='Yes', value='Bachelor’s or equivalent')

# %%
m_edu.sample(10)
# Out:
#                           Country  Student ID  Gender  \
# 2111318                     Spain       23776    Male
# 897325        Massachusetts (USA)        1088    Male
# 1552830               Switzerland         347  Female
# 900153                    Romania        2193    Male
# 1567452                     Chile        3740  Female
# 719294                    Iceland        1778  Female
# 1863316  Perm(Russian Federation)        1453  Female
# 1501475                   Belgium        3619    Male
# 1125389                     Spain        8827    Male
# 1127974                     Spain       11412  Female
#
#                     Mother - Highest Schooling <ISCED level 6>  \
# 2111318  She did not complete <ISCED level 1>               No
# 897325                       <ISCED level 3A>               No
# 1552830                  <ISCED level 3B, 3C>               No
# 900153                       <ISCED level 3A>               No
# ...

# %%
# Combine all columns into one variable column
m_edu = pd.melt(m_edu, 
                     id_vars=['Country','Student ID', 'Gender',
                            'Out-of-School Study Time - Homework',
                            'Out-of-School Study Time - Guided Homework',
                            'Out-of-School Study Time - Personal Tutor',
                            'Out-of-School Study Time - Commercial Company',
                            'Out-of-School Study Time - With Parent',
                            'Learning Time - Mathematics',
                            'Learning Time - Test Language',
                            'Learning Time - Science',
                            'Average_Math_Score',
                            'Average_Reading_Score',
                            'Average_Science_Score',
                            'Average_Total_Score',
                             'Education - Father'], var_name='Completed_edu - Mother', value_name='Education - Mother')

# %%
m_edu.sample(10)
# Out:
#             Country  Student ID  Gender  Out-of-School Study Time - Homework  \
# 107571       Brazil       16129    Male                                  5.0
# 223604  Switzerland        8867    Male                                 10.0
# 109186  Switzerland        7676    Male                                  4.0
# 200977        Spain       17523  Female                                  4.0
# 211450        Italy       13409    Male                                 10.0
# 81276         Spain        6024    Male                                  8.0
# 41994         Spain       21684  Female                                  8.0
# 19280         Italy       28769    Male                                 12.0
# 91001         Spain       15773    Male                                  3.0
# 232351        Italy       17953  Female                                  1.0
#
#         Out-of-School Study Time - Guided Homework  \
# 107571                                         3.0
# ...

# %%
# Remove all cases from melt where the education of the mother is either '0' or 'No'
m_edu = m_edu[(m_edu['Education - Mother'] != '0')] 
m_edu = m_edu[(m_edu['Education - Mother'] != 'No')]

# %%
# Check to see if 0's and No's have been removed
m_edu.sample(70)
# Out:
#                          Country  Student ID  Gender  \
# 20885                     Canada       18237    Male
# 14388         Russian Federation         671    Male
# 182547                     Spain       10273  Female
# 181644                     Italy       21620    Male
# 119012                     Italy       27987  Female
# 17829                      Spain       21667    Male
# 109479                     Spain       19625  Female
# 454                      Iceland        1483    Male
# 97068                     Israel         993    Male
# 13318                      Spain       10753    Male
# 183269                    Canada       18474    Male
# 211522               Switzerland       10783  Female
# 3691                      Canada        3887  Female
# 160444                     Italy       21408  Female
# 26560                     Norway        3365    Male
# 9490                     Austria        1787  Female
# 5                          Italy        4585    Male
# ...

# %%
# Remove 'Mother - Highest Schooling' since it is redundant
m_edu = m_edu[(m_edu['Completed_edu - Mother'] != 'Mother - Highest Schooling')]

# %%
m_edu['Education - Mother'].value_counts()
# Out:
# Upper secondary             19440
# Short-cycle tertiary        14762
# Post-secondary               5580
# Lower secondary              3964
# Bachelor’s or equivalent     2725
# Primary                       588
# Early childhood               176
# Name: Education - Mother, dtype: int64

# %%
# Completed_edu is no longer needed since it duplicates the information in 'Education - Mother'
m_edu.drop(columns=['Completed_edu - Mother'], axis=1, inplace=True)

# %%
m_edu.sample(10)
# Out:
#            Country  Student ID  Gender  Out-of-School Study Time - Homework  \
# 69269       Canada       18788    Male                                  4.0
# 48938   Luxembourg        4881    Male                                  3.0
# 106475   Singapore        3707    Male                                  3.0
# 64519        Italy       28901  Female                                 20.0
# 48869   Kazakhstan        2791  Female                                  4.0
# 48416       Israel        4753    Male                                  6.0
# 170204      Greece        1877    Male                                  5.0
# 182199       Spain        8827    Male                                  9.0
# 172418     Belgium        6310    Male                                  5.0
# 50157      Romania        4745  Female                                 25.0
#
#         Out-of-School Study Time - Guided Homework  \
# 69269                                          0.0
# ...

# %%
m_edu['Student ID'].duplicated().sum()
# Out:
# 23067

# %%
# Change datatypes into category, and put into order from lowest to highest
m_edu['Education - Mother'] = m_edu['Education - Mother'].astype('category')
m_edu['Education - Mother'] = m_edu['Education - Mother'].cat.set_categories(['Bachelor’s or equivalent', 
                                                                                        'Short-cycle tertiary', 
                                                                                        'Post-secondary', 
                                                                                        'Upper secondary',
                                                                                        'Lower secondary', 
                                                                                        'Primary', 
                                                                                        'Early childhood'], ordered=True)
m_edu.sort_values(['Education - Mother'], inplace=True)

# Remove duplicates and keep last, which is the highest level of education for the student's father
mother_edu_clean = m_edu.drop_duplicates(subset=['Student ID'], keep='first')

# %%
mother_edu_clean['Student ID'].duplicated().sum()
# Out:
# 0

# %%
print(pisa['STIDSTD'].nunique())
print(mother_edu_clean.shape)
# Out:
# 33806
# (24168, 17)

# %%
mother_edu_clean.head()
# Out:
#       Country  Student ID  Gender  Out-of-School Study Time - Homework  \
# 24170   Italy        4711  Female                                 22.0
# 24175   Italy        4508    Male                                  9.0
# 24176   Italy        4473    Male                                 13.0
# 24177   Italy        4460  Female                                 18.0
# 24182   Italy        3971    Male                                 21.0
#
#        Out-of-School Study Time - Guided Homework  \
# 24170                                         2.0
# 24175                                         2.0
# 24176                                         2.0
# 24177                                         0.0
# 24182                                         0.0
#
#        Out-of-School Study Time - Personal Tutor  \
# 24170                                        0.0
# 24175                                        1.0
# 24176                                        0.0
# ...

# %%
pisa_clean = mother_edu_clean.copy()

# %%
mother_edu_clean.head()
# Out:
#       Country  Student ID  Gender  Out-of-School Study Time - Homework  \
# 24170   Italy        4711  Female                                 22.0
# 24175   Italy        4508    Male                                  9.0
# 24176   Italy        4473    Male                                 13.0
# 24177   Italy        4460  Female                                 18.0
# 24182   Italy        3971    Male                                 21.0
#
#        Out-of-School Study Time - Guided Homework  \
# 24170                                         2.0
# 24175                                         2.0
# 24176                                         2.0
# 24177                                         0.0
# 24182                                         0.0
#
#        Out-of-School Study Time - Personal Tutor  \
# 24170                                        0.0
# 24175                                        1.0
# 24176                                        0.0
# ...

# %%
pisa_clean.replace(["NaN"], np.nan, inplace = True)
pisa_clean.dropna(inplace = True)

# %%
pisa_clean
# Out:
#         Country  Student ID  Gender  Out-of-School Study Time - Homework  \
# 24170     Italy        4711  Female                                 22.0
# 24175     Italy        4508    Male                                  9.0
# 24176     Italy        4473    Male                                 13.0
# 24177     Italy        4460  Female                                 18.0
# 24182     Italy        3971    Male                                 21.0
# 24185     Italy        3896  Female                                 20.0
# 24186     Italy        3796    Male                                 10.0
# 24187     Italy        3748  Female                                 30.0
# 24192     Italy        2772    Male                                  8.0
# 24196     Italy        5366    Male                                  7.0
# 24197     Italy        7271  Female                                  6.0
# 24209     Italy        6496    Male                                 10.0
# ...

# %%
pisa_clean.shape
# Out:
# (24168, 17)

# %%
# Create total of Out-of-School Study Time
pisa_clean['Out-of-School Study Time - Total'] = pisa_clean['Out-of-School Study Time - Homework'] + pisa_clean['Out-of-School Study Time - Guided Homework'] + pisa_clean['Out-of-School Study Time - Personal Tutor'] + pisa_clean['Out-of-School Study Time - Commercial Company'] + pisa_clean['Out-of-School Study Time - With Parent']

# Create total of Learning time (minutes per week)
pisa_clean['Learning Time - Total'] = pisa_clean['Learning Time - Mathematics'] + pisa_clean['Learning Time - Test Language'] + pisa_clean['Learning Time - Science']

# %%
list(pisa_clean)
# Out:
# ['Country',
#  'Student ID',
#  'Gender',
#  'Out-of-School Study Time - Homework',
#  'Out-of-School Study Time - Guided Homework',
#  'Out-of-School Study Time - Personal Tutor',
#  'Out-of-School Study Time - Commercial Company',
#  'Out-of-School Study Time - With Parent',
#  'Learning Time - Mathematics',
#  'Learning Time - Test Language',
#  'Learning Time - Science',
#  'Average_Math_Score',
#  'Average_Reading_Score',
#  'Average_Science_Score',
#  'Average_Total_Score',
#  'Education - Father',
#  'Education - Mother',
#  'Out-of-School Study Time - Total',
#  'Learning Time - Total']

# %%
pisa.shape
# Out:
# (485490, 635)

# %%
pisa_clean['Education - Mother'].value_counts()
# Out:
# Short-cycle tertiary        10185
# Upper secondary              4791
# Lower secondary              3057
# Bachelor’s or equivalent     2725
# Post-secondary               2646
# Primary                       588
# Early childhood               176
# Name: Education - Mother, dtype: int64

# %%
# Store the clean DataFrame in a CSV file
pisa_clean.to_csv("pisa_wrg.csv", index=False, encoding='utf8')
